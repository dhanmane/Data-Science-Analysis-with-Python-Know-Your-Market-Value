# %%
import os
import io
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)

            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                elif line == '\n':
                    inBody = True
            f.close()
            message = '\n'.join(lines)
            yield path, message

# %%
def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

data = DataFrame({'message': [], 'class': []})

# %%
data = data.append(dataFrameFromDirectory(
    '/Users/Dhanashree/Desktop/Dhanashree/SCU Coursework/PythonDS/Pro/emails/spam', 'spam'))

# %%
data = data.append(dataFrameFromDirectory('/Users/Dhanashree/Desktop/Dhanashree/SCU Coursework/PythonDS/Pro/emails/ham', 'ham'))

# %%
data.head()
# Out:
#                                                    class  \
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
#
#                                                                                               message
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  ##############################################...
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  I thought you might like these:\n\n1) Slim Dow...

# %%
data
# Out:
#                                                    class  \
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# /Users/Dhanashree/Desktop/Dhanashree/SCU Course...  spam
# ...

# %%
vectorizer= CountVectorizer()
counts= vectorizer.fit_transform(data['message'].values)

# %%
counts
# Out:
# <3000x62964 sparse matrix of type '<class 'numpy.int64'>'
# 	with 429785 stored elements in Compressed Sparse Row format>

# %%
ClassifierModel = MultinomialNB()

targets= data['class'].values

ClassifierModel.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
examples= ['Free Free Free', 'Free FREE FREE Sex', 'power of attorney request', 'meet you at 4.30 pm', 
           'Central Bank of Nigeria has 100 Million dollars for you', 'Get City card, get 71 litres of free fuel**', 'HI DHANASHREEMANE03, One Cover for every Family Member',
          'Hi dhanashreemane03 Full-body checkup for just Rs. 999']

example_counts= vectorizer.transform(examples)

predictions= ClassifierModel.predict(example_counts)

# %%
predictions
# Out:
# array(['spam', 'spam', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham'],
#       dtype='<U4')
