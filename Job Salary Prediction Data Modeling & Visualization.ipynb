# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %%
filename = "Cleaneddata - Sheet1.csv"

df = pd.read_csv(filename, header=0)
data = df

# %%
df.values
# Out:
# array([['AMG Technology Solutions', 72393.0, '1 to 3', 'Austin',
#         'Business Analyst'],
#        ['AMG Technology Solutions', 110696.5, '4 to 6', 'Austin',
#         'Business Analyst'],
#        ['AMG Technology Solutions', 149000.0, '7 to 10', 'Austin',
#         'Business Analyst'],
#        ...,
#        ['Accenture', 68791.0, '1 to 3', 'Austin', 'Business Analyst'],
#        ['Accenture', 108895.5, '4 to 6', 'Austin', 'Business Analyst'],
#        ['Accenture', 149000.0, '7 to 10', 'Austin', 'Business Analyst']], dtype=object)

# %% [markdown]
# # Salary Distribution

# %%
plt.xlabel("Salary Distribution")
plt.hist(df["Salary"], color = "pink")
plt.show()

# %% [markdown]
# # Comparing Salary with respect to Location

# %%
plt.barh(df["Location"], df["Salary"], align= "center", alpha = 0.5)
plt.ylabel("Location")
plt.xlabel("Salary in dollars")
plt.show()

# %% [markdown]
# # Comparing Salary with respect to Yrs of Experience

# %%
plt.scatter(df["Years of Experience"], df["Salary"], color = 'purple')
plt.xlabel("Years of Experience")
plt.ylabel("Salary in dollars")
plt.show()

# %%
exp = {'1 to 3': 0, '4 to 6': 1, '7 to 10': 2}
data['Years of Experience'] = data['Years of Experience'].map(exp)
data.head()
# Out:
#                Company Name    Salary  Years of Experience Location  \
# 0  AMG Technology Solutions   72393.0                    0   Austin
# 1  AMG Technology Solutions  110696.5                    1   Austin
# 2  AMG Technology Solutions  149000.0                    2   Austin
# 3                 Accenture   68791.0                    0   Austin
# 4                 Accenture  108895.0                    1   Austin
#
#           Job Title
# 0  Business Analyst
# 1  Business Analyst
# 2  Business Analyst
# 3  Business Analyst
# 4  Business Analyst

# %%
city = {"Austin": 0, "Berkley":1, "Boston": 2, "Chicago": 3, "Cupertino": 4, "Houston": 5, "Los Angeles": 6, 
        "Mountain View":7, "New York": 8, "Orlando": 9, "San Francisco":10, "San Jose": 11, "Seattle": 12}
data["Location"] = data["Location"].map(city)
data.head()
# Out:
#                Company Name    Salary  Years of Experience  Location  \
# 0  AMG Technology Solutions   72393.0                    0         0
# 1  AMG Technology Solutions  110696.5                    1         0
# 2  AMG Technology Solutions  149000.0                    2         0
# 3                 Accenture   68791.0                    0         0
# 4                 Accenture  108895.0                    1         0
#
#           Job Title
# 0  Business Analyst
# 1  Business Analyst
# 2  Business Analyst
# 3  Business Analyst
# 4  Business Analyst

# %%
data.tail()
# Out:
#                   Company Name    Salary  Years of Experience  Location  \
# 1384  AMG Technology Solutions  107000.0                    1         0
# 1385  AMG Technology Solutions  149000.0                    2         0
# 1386                 Accenture   68791.0                    0         0
# 1387                 Accenture  108895.5                    1         0
# 1388                 Accenture  149000.0                    2         0
#
#              Job Title
# 1384  Business Analyst
# 1385  Business Analyst
# 1386  Business Analyst
# 1387  Business Analyst
# 1388  Business Analyst

# %%
data.head(50)
# Out:
#                                     Company Name    Salary  \
# 0                       AMG Technology Solutions   72393.0
# 1                       AMG Technology Solutions  110696.5
# 2                       AMG Technology Solutions  149000.0
# 3                                      Accenture   68791.0
# 4                                      Accenture  108895.0
# 5                                      Accenture  153456.0
# 6                                           Dell   74396.0
# 7                                           Dell  110698.0
# 8                                           Dell  151000.0
# 9   Department Of Family And Protective Services   60852.0
# 10  Department Of Family And Protective Services   85363.0
# 11  Department Of Family And Protective Services  109874.0
# 12                             Yana Software inc   67284.0
# 13                             Yana Software inc  102017.5
# 14                             Yana Software inc  137000.0
# 15                                 Microinfo Inc   67035.0
# 16                                 Microinfo Inc   98017.5
# 17                                 Microinfo Inc  129000.0
# 18                        Robert Half Technology   70920.0
# 19                        Robert Half Technology  102995.0
# 20                        Robert Half Technology  135070.0
# 21                                      Mindtree   66776.0
# 22                                      Mindtree   97309.5
# 23                                      Mindtree  127843.0
# 24                       Benchmark International   63909.0
# 25                       Benchmark International  106454.5
# 26                       Benchmark International  149000.0
# 27                                 Gravitant Inc   76893.0
# 28                                 Gravitant Inc  113946.5
# 29                                 Gravitant Inc  151000.0
# 30                                       Experis  120000.0
# 31                                       Experis  154500.0
# 32                                       Experis  189000.0
# 33                                  Ashley Ellis  117444.0
# 34                                  Ashley Ellis  134722.0
# 35                                  Ashley Ellis  152000.0
# 36                                         Shell  101522.0
# 37                                         Shell  129261.0
# 38                                         Shell  157000.0
# 39                     Mason Frank International  111779.0
# 40                     Mason Frank International  139389.5
# 41                     Mason Frank International  167000.0
# 42                                     CGI Group   97979.0
# 43                                     CGI Group  125489.5
# 44                                     CGI Group  153000.0
# 45                                       Chevron   88864.0
# 46                                       Chevron  118432.0
# 47                                       Chevron  148000.0
# 48                                 Dynamics Jobs   93280.0
# 49                                 Dynamics Jobs  124640.0
#
#     Years of Experience  Location         Job Title
# 0                     0         0  Business Analyst
# 1                     1         0  Business Analyst
# 2                     2         0  Business Analyst
# 3                     0         0  Business Analyst
# 4                     1         0  Business Analyst
# 5                     2         0  Business Analyst
# 6                     0         0  Business Analyst
# 7                     1         0  Business Analyst
# 8                     2         0  Business Analyst
# 9                     0         0  Business Analyst
# 10                    1         0  Business Analyst
# 11                    2         0  Business Analyst
# 12                    0         0  Business Analyst
# 13                    1         0  Business Analyst
# 14                    2         0  Business Analyst
# 15                    0         0  Business Analyst
# 16                    1         0  Business Analyst
# 17                    2         0  Business Analyst
# 18                    0         0  Business Analyst
# 19                    1         0  Business Analyst
# 20                    2         0  Business Analyst
# 21                    0         0  Business Analyst
# 22                    1         0  Business Analyst
# 23                    2         0  Business Analyst
# 24                    0         0  Business Analyst
# 25                    1         0  Business Analyst
# 26                    2         0  Business Analyst
# 27                    0         0  Business Analyst
# 28                    1         0  Business Analyst
# 29                    2         0  Business Analyst
# 30                    0         1  Business Analyst
# 31                    1         1  Business Analyst
# 32                    2         1  Business Analyst
# 33                    0         5  Business Analyst
# 34                    1         5  Business Analyst
# 35                    2         5  Business Analyst
# 36                    0         5  Business Analyst
# 37                    1         5  Business Analyst
# 38                    2         5  Business Analyst
# 39                    0         5  Business Analyst
# 40                    1         5  Business Analyst
# 41                    2         5  Business Analyst
# 42                    0         5  Business Analyst
# 43                    1         5  Business Analyst
# 44                    2         5  Business Analyst
# 45                    0         5  Business Analyst
# 46                    1         5  Business Analyst
# 47                    2         5  Business Analyst
# 48                    0         5  Business Analyst
# 49                    1         5  Business Analyst

# %%
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

X = data.iloc[:, 2:3]
y = data.iloc[:, 1:2]

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

train_x_set = xtrain
train_y_set = ytrain
test_x_set = xtest
test_y_set = ytest

# %%
regr = linear_model.LinearRegression()

# Train the model using the training sets
clf = regr.fit(train_x_set, train_y_set)

# Make predictions using the testing set
Sal_y_pred = regr.predict(test_x_set)

#Mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(test_y_set, Sal_y_pred))
# Out:
# Mean squared error: 481072086.71

# %%
clf.score(test_y_set, Sal_y_pred)
# Out:
# -28564941256.487541

# %% [markdown]
# # Knn Algorithm

# %%
from sklearn.neighbors import KNeighborsRegressor

X = data.iloc[:, 2:3]
y = data.iloc[:, 1:2]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

classifier = KNeighborsRegressor()

clf1 = classifier.fit(train_x_set, train_y_set)

# %%
clf1.predict([[0]])
# Out:
# array([[ 104632.96]])
